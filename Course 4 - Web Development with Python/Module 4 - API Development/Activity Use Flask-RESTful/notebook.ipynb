# %%
# %pip install nest_asyncio flask flask_restful
# Out:
# Requirement already satisfied: nest_asyncio in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (1.6.0)
# Requirement already satisfied: flask in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (3.1.2)
# Requirement already satisfied: flask_restful in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (0.3.10)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask) (3.1.5)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask_restful) (10.0.1)
# Requirement already satisfied: six>=1.3.0 in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask_restful) (1.17.0)
# Requirement already satisfied: pytz in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from flask_restful) (2025.2)
# Requirement already satisfied: colorama in c:\users\mamat\microsoft_python_development_professional_certificate\venv\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nest_asyncio
from flask import Flask, request
from flask_restful import Api, Resource
from threading import Thread

# %%
books = [
    {"isbn": "1234567890", "title": "The Great Gatsby", "author": "F. Scott Fitzgerald", "price": 10.99},
    {"isbn": "0987654321", "title": "1984", "author": "George Orwell", "price": 8.99}
]

# %%
app = Flask(__name__)
api = Api(app)

# %%
def get(self, isbn=None):
    if isbn:
        for book in books:
            if book['isbn'] == isbn:
                return book, 200
        return {"message": "Book not found"}, 404
    return books, 200

# %%
def post(self):
    new_book = request.json
    books.append(new_book)
    return new_book, 201

# %%
def put(self, isbn):
    for book in books:
        if book['isbn'] == isbn:
            book.update(request.json)
            return book, 200
    return {"message": "Book not found"}, 404

# %%
def delete(self, isbn):
    global books
    books = [book for book in books if book['isbn'] != isbn]
    return {"message": "Book deleted"}, 200

# %%
api.add_resource(Book, '/books', '/books/<string:isbn>')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 api.add_resource(Book, '/books', '/books/<string:isbn>')
#
# NameError: name 'Book' is not defined

# %%
nest_asyncio.apply()
def run_app():
    app.run(port=5000, debug=False)

thread = Thread(target=run_app)
thread.start()

print("API is running! Test it at http://127.0.0.1:5000/books")
# Out:
# API is running! Test it at http://127.0.0.1:5000/books
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
